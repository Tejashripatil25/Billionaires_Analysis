# %% [markdown]
# ## Billionaires Analysis with Python
# #### The dataset that I am using to analyze the data about billionaires around the world was curated by Forbes and is downloaded from Kaggle. The dataset contains information about global billionaires in 2021, including their:
# #### Names
# #### Net Worth
# #### Country
# #### Source
# #### Rank
# #### Age
# #### Industry

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Billionaire.csv")
df.head()
# Out:
#                        Name NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos   $177 B  United States         Amazon     1
# 1                 Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France           LVMH     3
# 3                Bill Gates   $124 B  United States      Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States       Facebook     5
#
#     Age          Industry
# 0  57.0        Technology
# 1  49.0        Automotive
# 2  72.0  Fashion & Retail
# 3  65.0        Technology
# 4  36.0        Technology

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755 entries, 0 to 2754
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      2755 non-null   object
#  1   NetWorth  2755 non-null   object
#  2   Country   2755 non-null   object
#  3   Source    2755 non-null   object
#  4   Rank      2755 non-null   int64
#  5   Age       2676 non-null   float64
#  6   Industry  2755 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 150.8+ KB

# %%
def solution(dff):
    print('shape:',df.shape,'\n')
    print('dtype:',df.dtypes)
solution(df)
# Out:
# shape: (2755, 7)
#
# dtype: Name         object
# NetWorth     object
# Country      object
# Source       object
# Rank          int64
# Age         float64
# Industry     object
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'NetWorth', 'Country', 'Source', 'Rank', 'Age', 'Industry'], dtype='object')

# %%
df.isna().sum()
# Out:
# Name         0
# NetWorth     0
# Country      0
# Source       0
# Rank         0
# Age         79
# Industry     0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isna().sum()
# Out:
# Name        0
# NetWorth    0
# Country     0
# Source      0
# Rank        0
# Age         0
# Industry    0
# dtype: int64

# %%
df.dropna()
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
#        Age          Industry
# ...

# %%
data = df.sort_values(by = ["NetWorth"], ascending=False).head(10)
plt.figure(figsize=(10,12))
data.plot(kind='bar')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# #### According to Networth Jeff Bezos is the top most Billionaire.

# %%
df[['Source']].value_counts().head()
# Out:
# Source
# real estate        171
# pharmaceuticals     99
# investments         90
# diversified         85
# software            62
# dtype: int64

# %%
a = df["Source"].value_counts().head()
index = a.index
sources = a.values
plt.figure(figsize=(5, 5))
plt.pie(sources, labels=index,autopct='%f%%')
plt.title("Top 5 Sources to Become a Billionaire", fontsize=16)
plt.show()

# %% [markdown]
# #### The above Graph is shows that Top  most 5 Sourses to Become a Billionaire in which real estate is number one Source to become a Billionaire.

# %%
df[['Industry']].value_counts().head()
# Out:
# Industry
# Finance & Investments    371
# Technology               365
# Manufacturing            331
# Fashion & Retail         273
# Healthcare               221
# dtype: int64

# %%
s = df["Industry"].value_counts().head()
index = s.index
Industry = s.values
plt.figure(figsize=(5, 5))
plt.pie(Industry, labels=index,autopct='%f%%')
plt.title("Top 5 Industries with most No.of billionaires",fontsize=16)
plt.show()

# %% [markdown]
# #### The above Graph is shows that in Finance & Investments industry people has more chance to become billionaires.

# %%
df[['Country']].value_counts().head()
# Out:
# Country
# United States    724
# China            626
# India            140
# Germany          136
# Russia           118
# dtype: int64

# %%
c = df["Country"].value_counts().head()
index = c.index
Country = c.values
plt.figure(figsize=(5, 5))
plt.pie(Country, labels=index,autopct='%f%%')
plt.title("Top 5 Countries with most No.of billionaires",fontsize=16)
plt.show()

# %% [markdown]
# #### The above visualization shows that the United States and China are the countries from which most people become billionaires. So that means the business environment and the startup success rate is really good in the US and China compared to the rest of the world.

# %% [markdown]
# ### Summary
# #### So this is how you can find patterns among billionaires around the world to analyze the business environment of countries. The success of a business or startup depends a lot on the business environment of a country. At the end of the analysis of global billionaires, I found that China and the United States are the countries with the most billionaires which concludes that the business environment and the success rate of a startup is much better in the US and China than in the rest of the world.
